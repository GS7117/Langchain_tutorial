# %% [markdown]
# # **LLM CALL**

# %%
import os
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

completion = client.chat.completions.create(
    model="gpt-5-mini",
    messages=[
        {"role": "developer", "content": "Talk like a pirate."},
        {
            "role": "user",
            "content": "Tell me a fun fact!",
        },
    ],
)

print(completion.choices[0].message.content)
# Out:
# Arrr! Fun fact, matey: an octopus has three hearts and blue blood. Two hearts pump blood to the gills, the third sends it to the rest o' the body, and their blood's blue 'cause it uses copper-based hemocyanin to carry oxygen — perfect for cold, low-oxygen seas. Arrr!

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
import os

load_dotenv()


if os.environ.get("OPENAI_API_KEY") :
    print("Bro API key variable is found")

else :
    raise ValueError("OPENAI_APKI_KEY not found")
# Out:
# Bro API key variable is found

# %%
llm_openai = ChatOpenAI(model="gpt-5-mini", temperature=0)
llm_openai.invoke("Bro tell me a fun fact").content

# %%
from langchain.chat_models import init_chat_model

llm_openai =  init_chat_model(model="gpt-5-mini")

llm_openai.invoke("Hello how is the temprature in melbourne?").content
# Out:
# 'I can’t fetch live weather from here. Do you mean Melbourne, Australia or Melbourne, Florida (or another Melbourne)?\n\nIf you mean Melbourne, Australia: it’s early July (winter there), so typical daytime highs are around 12–15°C (54–59°F) and nighttime lows about 5–8°C (41–46°F). Expect cool, changeable conditions and possible showers.\n\nIf you want the current temperature and forecast, you can check:\n- Australian Bureau of Meteorology (bom.gov.au)\n- Weather.com / AccuWeather / Google Weather\nOr tell me which Melbourne and I’ll give more detailed guidance on where to check or what to expect this week.'
